# %%
# %run commen_stock.ipynb
# Out:
# c:\Users\2199222\AppData\Local\Programs\Python\Python312\Lib\site-packages\nbformat\__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# The system cannot find the file specified.

# %%
import time

# %%
option_dataframe = pd.DataFrame(columns=['CALL_OI','PUT_OI','CALL_COI','PUT_COI' ,'CALL_TBQ','CALL_TSQ','PUT_TBQ','PUT_TSQ',])
max_df =  pd.DataFrame(columns=['max_CS','max_CB','max_CT','max_CTOI','max_COI','max_CCOI','STP','max_PCOI','max_POI','max_PTOI','max_PT',
                            'max_PB','max_PS'])

# %%
url ='https://www.nseindia.com/api/option-chain-equities?symbol=AXISBANK'

header = {
    "Connection": "keep-alive",
    "Cache-Control": "max-age=0",
    "DNT": "1",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/111.0.0.0 Safari/537.36",
    "Sec-Fetch-User": "?1", "Accept": "*/*", "Sec-Fetch-Site": "none", "Sec-Fetch-Mode": "navigate",
    "Accept-Encoding": "gzip, deflate, br", "Accept-Language": "en-US,en;q=0.9,hi;q=0.8"
    }
session = requests.session()
nse_live = session.get("http://nseindia.com", headers=header)


mc_url = 'https://www.moneycontrol.com/india/stockpricequote/banks-private-sector/axisbank/AB16'

# %%
def main_dis_run(option_dataframe,max_df,session,url,header,mc_url):
   try:
         run_main(option_dataframe,max_df,session,url,header,mc_url)
   except Exception as e:
         print(f'trying to retry to re-slove issue')
      #    raise e
      #    time.sleep(180)
         main_dis_run(option_dataframe,max_df,session,url,header,mc_url)

main_dis_run(option_dataframe, max_df, session,url,header,mc_url)
# Out:
#    CALL_OI   PUT_OI  CALL_COI  PUT_COI   CALL_TBQ   CALL_TSQ    PUT_TBQ  \
# 0  44881.0  20409.0   -1445.0  -1075.0  9396875.0  5475625.0  8004375.0
# 2  44881.0  20409.0   -1445.0  -1075.0  9396875.0  5475625.0  8004375.0
#
#      PUT_TSQ  VOL_DIFF  BUY_DIFF  SELL_DIFF  Signal
# 0  2774375.0  1.652967  0.902912   1.107528       0
# 2  2774375.0  1.652967  0.902912   1.107528       0
#   max_CS max_CB max_CT max_CTOI max_COI max_CCOI   STP max_PCOI max_POI  \
# 0   1200   1150   1200     1200    1200     1180  1159     1170    1100
# 1   1180   1300   1180     1300    1300     1170  1159     1130    1200
# 2   1300   1190   1170     1180    1180     1210  1159     1230    1150
#
#   max_PTOI max_PT max_PB max_PS
# 0     1100   1150   1100   1100
# 1     1200   1160   1110   1090
# 2     1150   1170   1080   1150
#     CALL_IV  spread_call  CALL_OI  CALL_CHNG_OI   CALL_BQ   CALL_SA  \
# 3      0.00       461.10     20.0          -8.0   36250.0   55625.0
# 8     53.70      1760.25      9.0          -2.0   50000.0   55625.0
# 13    20.69      1181.70    213.0        -104.0   48125.0   84375.0
# 18    20.98       596.25   1385.0        -275.0  854375.0  129375.0
# 23    20.84      1867.25   9766.0         -87.0  409375.0  740000.0
# 28    24.96      1247.35   2945.0        -308.0  372500.0  283125.0
# 33    30.88     11873.55   5493.0        -150.0  736875.0  320625.0
# 38    33.68     31249.45    769.0         -52.0  243125.0  131250.0
# 43    37.02      9374.75    854.0         -80.0  285625.0   90625.0
# 47    46.66      1249.80    129.0           0.0  134375.0   19375.0
#
#     STRICK_PRICE    PUT_SA    PUT_BQ  PUT_CHNG_OI  PUT_OI  spread_put  PUT_IV  \
# 3           1000  103750.0  351875.0        -17.0  1101.0      624.35   36.63
# 8           1050   88125.0  224375.0        -58.0   760.0     1248.90   29.20
# 13          1100  188125.0  668750.0       -445.0  2335.0      621.40   24.25
# 18          1150  110625.0  451875.0        -87.0  1854.0     1236.40   21.50
# 23          1200   58125.0   77500.0        -73.0  1877.0      582.80   22.40
# 28          1250   46875.0   51875.0        -35.0   405.0      539.10   32.30
# 33          1300   52500.0   71250.0        -19.0   279.0      491.50    0.00
# 38          1350   41250.0   41250.0          0.0    64.0     4194.10    0.00
# 43          1400   41250.0   36875.0          0.0    26.0     4144.25    0.00
# 47          1500       0.0       0.0          0.0     0.0        0.00    0.00
#
#    Scenario
# 3   S-Cover
# 8   S-Cover
# 13  S-Cover
# 18  S-Cover
# 23  S-Cover
# 28  S-Cover
# 33  S-Cover
# 38  S-Cover
# 43  S-Cover
# 47     None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 10
#       6       #    raise e
#       7       #    time.sleep(180)
#       8          main_dis_run(option_dataframe,max_df,session,url,header,mc_url)
# ---> 10 main_dis_run(option_dataframe, max_df, session,url,header,mc_url)
#
# Cell In[5], line 3, in main_dis_run(option_dataframe, max_df, session, url, header, mc_url)
#       1 def main_dis_run(option_dataframe,max_df,session,url,header,mc_url):
#       2    try:
# ----> 3          run_main(option_dataframe,max_df,session,url,header,mc_url)
#       4    except Exception as e:
#       5          print(f'trying to retry to re-slove issue')
#
# File ~\AppData\Local\Temp\ipykernel_21080\2465337960.py:28, in run_main(option_dataframe, max_df, session, url, header, mc_url)
#      24 display(max_df.tail(3),display_df[(display_df.STRICK_PRICE.isin(range_price))]
#      25 # ,max_df_2.tail(3)
#      26         )
#      27 # display(option_dataframe.tail(3))
# ---> 28 time.sleep(2)
#
# KeyboardInterrupt:
