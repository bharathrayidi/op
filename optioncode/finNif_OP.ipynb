# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# import sys
# # Add the path of the virtual environment site-packages to Colab's system path
# sys.path.append("/content/drive/MyDrive/virtual_env/lib/python3.10/site-packages")

# %%
# %run commen.ipynb

# %%
option_dataframe = pd.DataFrame(columns=['CALL_OI','PUT_OI','CALL_COI','PUT_COI' ,'CALL_TBQ','CALL_TSQ','PUT_TBQ','PUT_TSQ',])
max_df =  pd.DataFrame(columns=['max_CS','max_CB','max_CT','max_CTOI','max_COI','max_CCOI','STP','max_PCOI','max_POI','max_PTOI','max_PT',
                            'max_PB','max_PS'])

# %%
url ='https://www.nseindia.com/api/option-chain-indices?symbol=FINNIFTY'

header = {
    "Connection": "keep-alive",
    "Cache-Control": "max-age=0",
    "DNT": "1",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/111.0.0.0 Safari/537.36",
    "Sec-Fetch-User": "?1", "Accept": "*/*", "Sec-Fetch-Site": "none", "Sec-Fetch-Mode": "navigate",
    "Accept-Encoding": "gzip, deflate, br", "Accept-Language": "en-US,en;q=0.9,hi;q=0.8"
    }
session = requests.session()
nse_live = session.get("http://nseindia.com", headers=header)

mc_url = 'https://www.moneycontrol.com/indian-indices/nifty-fin-service-47.html'

# %%
def main_dis_run(option_dataframe,max_df,session,url,header,mc_url):
   try:
         run_main(option_dataframe,max_df,session,url,header,mc_url)
   except Exception as e:
         print(f'trying to retry to re-slove issue')
        #  raise e
         main_dis_run(option_dataframe,max_df,session,url,header,mc_url)

main_dis_run(option_dataframe, max_df, session,url,header,mc_url)
# Out:
#      CALL_OI     PUT_OI   CALL_COI    PUT_COI    CALL_TBQ    CALL_TSQ  \
# 0  2072081.0  2049356.0  1092728.0  1496502.0  13329760.0  18637240.0
# 1  2021045.0  2012675.0  1041692.0  1459821.0  13329760.0  18637240.0
# 3  2021045.0  2012675.0  1041692.0  1459821.0  13329760.0  18637240.0
#
#      PUT_TBQ     PUT_TSQ  VOL_DIFF  BUY_DIFF  SELL_DIFF  Signal
# 0  7517800.0  20989200.0   1.01272  1.312136   0.762116       0
# 1  7517800.0  20989200.0   1.01272  1.312136   0.762116       0
# 3  7517800.0  20989200.0   1.01272  1.312136   0.762116       0
#   max_CS max_CB max_CT max_CTOI max_COI max_CCOI    STP max_PCOI max_POI  \
# 0  23700  23650  23650    23700   23700    23700  23662    23650   23650
# 1  23650  23500  23700    23650   23650    23650  23662    23600   23600
# 2  24200  23600  23750    23800   24000    23800  23662    23550   23000
#
#   max_PTOI max_PT max_PB max_PS
# 0    23650  23650  23700  23650
# 1    23600  23600  23750  23600
# 2    23000  23550  23800  23500
# ...
