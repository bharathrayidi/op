# %%
# %run commen_stock.ipynb
# Out:
# c:\Users\2199222\AppData\Local\Programs\Python\Python312\Lib\site-packages\nbformat\__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# The system cannot find the file specified.

# %%
import time

# %%
option_dataframe = pd.DataFrame(columns=['CALL_OI','PUT_OI','CALL_COI','PUT_COI' ,'CALL_TBQ','CALL_TSQ','PUT_TBQ','PUT_TSQ',])
max_df =  pd.DataFrame(columns=['max_CS','max_CB','max_CT','max_CTOI','max_COI','max_CCOI','STP','max_PCOI','max_POI','max_PTOI','max_PT',
                            'max_PB','max_PS'])

# %%
url ='https://www.nseindia.com/api/option-chain-equities?symbol=ICICIBANK'

header = {
    "Connection": "keep-alive",
    "Cache-Control": "max-age=0",
    "DNT": "1",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/111.0.0.0 Safari/537.36",
    "Sec-Fetch-User": "?1", "Accept": "*/*", "Sec-Fetch-Site": "none", "Sec-Fetch-Mode": "navigate",
    "Accept-Encoding": "gzip, deflate, br", "Accept-Language": "en-US,en;q=0.9,hi;q=0.8"
    }
session = requests.session()
nse_live = session.get("http://nseindia.com", headers=header)


mc_url = 'https://www.moneycontrol.com/india/stockpricequote/banks-private-sector/icicibank/ICI02'

# %%
def main_dis_run(option_dataframe,max_df,session,url,header,mc_url):
   try:
         run_main(option_dataframe,max_df,session,url,header,mc_url)
   except Exception as e:
         print(f'trying to retry to re-slove issue')
      #    raise e
      #    time.sleep(180)
         main_dis_run(option_dataframe,max_df,session,url,header,mc_url)

main_dis_run(option_dataframe, max_df, session,url,header,mc_url)
# Out:
# Exception ignored in: <function _collection_gced at 0x0000018A3EBDE160>
# Traceback (most recent call last):
#   File "c:\Users\2199222\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\event\registry.py", line 108, in _collection_gced
#     ref = cast("weakref.ref[RefCollection[EventTarget]]", ref)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\2199222\AppData\Local\Programs\Python\Python312\Lib\typing.py", line 2173, in cast
#     def cast(typ, val):
#
# KeyboardInterrupt:
#    CALL_OI   PUT_OI  CALL_COI  PUT_COI    CALL_TBQ   CALL_TSQ    PUT_TBQ  \
# 0  50150.0  21161.0    1062.0   -240.0  12175100.0  6398000.0  8317400.0
# 2  50150.0  21161.0    1062.0   -240.0  12175100.0  6398000.0  8317400.0
#
#      PUT_TSQ  VOL_DIFF  BUY_DIFF  SELL_DIFF  Signal
# 0  2714600.0  1.784366  1.011845   0.988294       0
# 2  2714600.0  1.784366  1.011845   0.988294       0
#   max_CS max_CB max_CT max_CTOI max_COI max_CCOI   STP max_PCOI max_POI  \
# 0   1200   1170   1200     1220    1220     1190  1168     1170    1150
# 1   1220   1160   1180     1250    1250     1180  1168     1160    1160
# 2   1250   1300   1190     1200    1200     1210  1168     1140    1100
#
#   max_PTOI max_PT max_PB max_PS
# 0     1150   1180   1100   1160
# 1     1160   1170   1120   1110
# 2     1180   1150   1150   1100
#     CALL_IV  spread_call  CALL_OI  CALL_CHNG_OI   CALL_BQ   CALL_SA  \
# 0      0.00      6128.35      4.0           0.0   41300.0   41300.0
# 3      0.00     12477.50      0.0           0.0   41300.0   47600.0
# 8     22.30       623.15    227.0          24.0   54600.0   55300.0
# 13    19.77       666.00    695.0          -3.0   68600.0   72100.0
# 18    19.39      6290.65   5367.0         202.0  459200.0  620900.0
# 23    23.46      2797.05   6226.0          77.0  613900.0  476000.0
# 28    27.70      6298.85   4296.0        -183.0  812700.0  331800.0
# 33    33.47      5599.25   1034.0         -34.0  522200.0  119700.0
# 36    37.98      6299.55    648.0         -16.0  287000.0  129500.0
#
#     STRICK_PRICE    PUT_SA    PUT_BQ  PUT_CHNG_OI  PUT_OI  spread_put  PUT_IV  \
# 0           1000  120400.0  294000.0        -39.0   633.0     4899.55   36.41
# 3           1050   58100.0   52500.0         15.0    83.0     8399.25   28.87
# 8           1100  141400.0  707000.0       -224.0  1935.0     4897.55   24.21
# 13          1150   95900.0  695100.0         75.0  2373.0     1390.65   20.34
# 18          1200   67200.0   90300.0       -120.0  1574.0     1365.90   19.96
# 23          1250   49700.0   53900.0         -2.0   487.0      623.05   24.94
# 28          1300   74200.0   61600.0        -16.0   392.0      575.45   39.74
# 33          1350   44800.0   41300.0          0.0    10.0     9627.85    0.00
# 36          1400   35700.0   41300.0          0.0     6.0     1878.10    0.00
#
#    Scenario
# 0   S-Cover
# 3      None
# 8   L-Cover
# 13  S-Cover
# 18  L-Cover
# 23  L-Cover
# 28  S-Cover
# 33  S-Cover
# 36  S-Cover
