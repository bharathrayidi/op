# %%
# %run commen.ipynb
# Out:
# c:\Users\2199222\AppData\Local\Programs\Python\Python312\Lib\site-packages\nbformat\__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# The system cannot find the file specified.

# %%
option_dataframe = pd.DataFrame(columns=['CALL_OI','PUT_OI','CALL_COI','PUT_COI' ,'CALL_TBQ','CALL_TSQ','PUT_TBQ','PUT_TSQ',])
max_df =  pd.DataFrame(columns=['max_CS','max_CB','max_CT','max_CTOI','max_COI','max_CCOI','STP','max_PCOI','max_POI','max_PTOI','max_PT',
                            'max_PB','max_PS'])

# %%
url ='https://www.nseindia.com/api/option-chain-indices?symbol=NIFTY'


header = {
    "Connection": "keep-alive",
    "Cache-Control": "max-age=0",
    "DNT": "1",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/111.0.0.0 Safari/537.36",
    "Sec-Fetch-User": "?1", "Accept": "*/*", "Sec-Fetch-Site": "none", "Sec-Fetch-Mode": "navigate",
    "Accept-Encoding": "gzip, deflate, br", "Accept-Language": "en-US,en;q=0.9,hi;q=0.8"
    }
session = requests.session()
nse_live = session.get("http://nseindia.com", headers=header)

mc_url = 'https://www.moneycontrol.com/indian-indices/nifty-50-9.html'

# %%
def main_dis_run(option_dataframe,max_df,session,url,header,mc_url):
   try:
         run_main(option_dataframe,max_df,session,url,header,mc_url)
   except Exception as e:
         print(f'trying to retry to re-slove issue')
      #    raise e
         main_dis_run(option_dataframe,max_df,session,url,header,mc_url)

main_dis_run(option_dataframe, max_df, session,url,header,mc_url)
# Out:
#      CALL_OI     PUT_OI   CALL_COI    PUT_COI     CALL_TBQ    CALL_TSQ  \
# 1  9508144.0  5742270.0  1983311.0  1547908.0  727545550.0  61363625.0
# 2  9508144.0  5742270.0  1983311.0  1547908.0  727545550.0  61363625.0
# 3  9508753.0  5742354.0  1983920.0  1547888.0  727459825.0  61579975.0
# 4  9508753.0  5742354.0  1983920.0  1547888.0  727459825.0  61579975.0
# 6  9196968.0  5742354.0  1839040.0  1547888.0  686867350.0  60591550.0
#
#        PUT_TBQ     PUT_TSQ  VOL_DIFF  BUY_DIFF  SELL_DIFF  Signal
# 1  693361475.0  37284275.0  1.134084  1.013389   0.986788      -1
# 2  693361475.0  37284275.0  1.134084  1.013389   0.986788       0
# 3  692239975.0  38264875.0  1.136030  1.015793   0.984453      -1
# 4  692239975.0  38264875.0  1.136030  1.015793   0.984453       0
# 6  688364050.0  40664950.0  1.056095  0.971396   1.029447       0
#   max_CS max_CB max_CT max_CTOI max_COI max_CCOI    STP max_PCOI max_POI  \
# 0  24200  23600  23600    23600   24000    23600  23572    23600   23000
# 1  24500  23500  24000    24000   24200    23900  23572    23500   23500
# 2  24400  24000  23800    24200   23600    24000  23572    23000   23600
#
#   max_PTOI max_PT max_PB max_PS
# 0    23000  23500  23500  22800
# 1    23500  23600  23400  22500
# 2    23600  23550  23600  22900
#        Action   PTB  Call_IV   Call_OI  Call_COI     Call_BQ    Call_SQ  \
# 30  No Action   NaN     0.00    9988.0    5999.0  16921900.0    64475.0
# 31  No Action   NaN     0.00    5528.0    2476.0  17973550.0    33375.0
# 32  No Action   NaN     0.00   34165.0   25233.0  26215075.0   143100.0
# 33  No Action   NaN     8.71   29953.0   17387.0  22314150.0    99975.0
# 34  No Action   NaN    10.35  174986.0  100391.0  39775725.0   588350.0
# 35    Buy Put  60.3    10.98  173035.0  114996.0  28720475.0   599475.0
# 36  No Action   NaN    11.54  494773.0  363250.0  40895125.0  2135275.0
# 37  No Action   NaN    12.54  203183.0  126091.0  26625875.0   931325.0
# 38  No Action   NaN     0.00       0.0       0.0         0.0        0.0
# 39  No Action   NaN    14.32  180055.0   80664.0  20446725.0   773100.0
# 40  No Action   NaN    15.06  386798.0   74861.0  34869275.0  1707075.0
# 41  No Action   NaN    15.63  179554.0   64201.0  18345750.0   677525.0
#
#     Current Price      STP     Put_SQ      Put_BQ   Put_COI    Put_OI  Put_IV  \
# 30        23573.2  23300.0  1096450.0  26410525.0   10151.0  255411.0   17.35
# 31        23573.2  23350.0   605150.0  19318275.0   67307.0  146810.0   16.84
# 32        23573.2  23400.0  1045650.0  36049750.0  130801.0  256281.0   16.30
# 33        23573.2  23450.0   570575.0  24282775.0   64953.0  140128.0   16.13
# 34        23573.2  23500.0  1642975.0  45598550.0  172949.0  359723.0   16.09
# 35        23573.2  23550.0   842825.0  31744550.0  130638.0  210141.0   16.30
# 36        23573.2  23600.0  1029575.0  33919450.0  177723.0  305990.0   16.82
# 37        23573.2  23650.0   242550.0  23631650.0   36968.0   87675.0   17.88
# 38        23573.2  23700.0   233700.0  24985200.0   11971.0  113056.0   19.36
# 39        23573.2  23750.0    66600.0  14934150.0    -626.0   25837.0   21.13
# 40        23573.2  23800.0    76400.0  16547725.0    -947.0   49977.0   22.97
# 41        23573.2  23850.0    33850.0   9195375.0    -485.0   22442.0   24.58
#
#     Put-Call Ratio
# 30       25.571786
# 31       26.557525
# 32        7.501273
# 33        4.678263
# 34        2.055724
# 35        1.214442
# 36        0.618445
# 37        0.431508
# 38             inf
# 39        0.143495
# 40        0.129207
# 41        0.124987
